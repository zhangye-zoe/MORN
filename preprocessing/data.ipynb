# %%
import h5py

# %%
path = '/data5/zhangye/trident/trident_processed_LUSC/20x_256px_0px_overlap/features_uni_v1/TCGA-56-8625-01Z-00-DX1.11AADFB3-33FF-4EAA-B423-CD0F07163747.h5'
with h5py.File(path, 'r') as f:
    print(f.keys())

    print(f['features'][:10])
# Out:
# <KeysViewHDF5 ['coords', 'features']>
# [[ 1.8935559  -1.7968162   0.44662958 ...  0.62359834 -1.6499554
#    0.8457913 ]
#  [-0.5672079  -2.8377395   1.705829   ...  0.94050545 -1.3175168
#    1.2597742 ]
#  [-0.23134297 -1.2890946   0.0482286  ...  1.4828889   0.41471085
#    0.48431247]
#  ...
#  [ 0.70683765 -0.20337635  0.01770326 ... -0.04079453  0.9289757
#   -0.8102826 ]
#  [ 1.6724435  -2.2287395  -1.014308   ... -0.93990743 -0.32484832
#   -0.9468292 ]
#  [ 0.12043336 -0.81682086  0.791039   ... -0.08060433  2.5178668
#    0.0384651 ]]
